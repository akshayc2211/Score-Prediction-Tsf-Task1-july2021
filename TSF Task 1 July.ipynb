# %%
   Data Science and Business Analytics Task - The Spark Foundation
    
     # Prediction using Supervised ML BY
        
        AKSHAY CHOUDHARY

# %%
PROBLEM STATEMENT-

# Predict the percentage of an student based on the no. of study hours

# %%
#Importimg Module

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the Dataset & finding first five Rows

s = pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
s.head()

# %%
#Finding Rows & column

s.shape

# %%
# Viewing some basic statistical details

s.describe()

# %%
# Plotting Hours vs Percentage of score

plt.scatter(s['Hours'], s ['Scores'])
plt.title('Hours vs Percentage')
plt.xlabel('Studied hours')
plt.ylabel('Scores')
plt.show()

# %%
# x will take all the value, except the last columnn which is dependent varible

x = s.iloc[:, :-1].values
y = s.iloc[:, -1].values
print('x:  ',x)
print('y:  ',y)

# %%
# Splitting train and test sets

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.3, random_state = 0)

# %%
# Training linear Regression model on the training set

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)

# %%
# Plotting the Regression line

line = reg.coef_ *x+reg.intercept_
#plotting for the test data
plt.scatter(x,y)
plt.plot(x,line,color='yellow')
plt.show()

# %%
#Predicting the test set results

y_pred = reg.predict(x_test)
print(y_pred)

# %%
# Plotting the training set results

y_pred=reg.predict(x_test)
print(y_pred)

# %%
# Plotting the training set results

plt.scatter(x_train, y_train, color = 'purple')
plt.plot(x_train, reg.predict(x_train),color='yellow')
plt.title('Training set')
plt.xlabel('Hours studied')
plt.ylabel('Percentage of Marks')
plt.show()

# %%
# Plotting the test set results

plt.scatter(x_test, y_test, color = 'purple')
plt.plot(x_test, reg.predict(x_test),color='yellow')
plt.title('Test set')
plt.xlabel('Hours studied')
plt.ylabel('Percentage of Marks')
plt.show()

# %%
# Comparing the actul value with the predicted values

dataset = pd.DataFrame({'Actutal': y_test,'Predicted':y_pred})
print(dataset)

# %%
# Predicting the score


dataset = np.array(9.25)
dataset = np.reshape(dataset, (-1,1))
pred = reg.predict(dataset)
print("If student studies 9.25 hours/day, the score will be {}.".format(pred))

# %%
# Computing Error metrices

from sklearn.metrics import r2_score
print('The R-square of model is: ',r2_score(y_test, y_pred))
